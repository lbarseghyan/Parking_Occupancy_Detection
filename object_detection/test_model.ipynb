# %%
import os
from ultralytics import YOLO

# %%
os.chdir('..')
# Out:
# WARNING ⚠️ Ultralytics settings reset to defaults. This is normal and may be due to a recent ultralytics package update, but may have overwritten previous settings.
# View and update settings with 'yolo settings' or at '/Users/laurabarseghyan/Library/Application Support/Ultralytics/settings.yaml'

# %%
YOLO('object_detection/models/detect/singleclass/weights/yolov8_cars.pt').val('/Users/laurabarseghyan/Desktop/CapstoneProject/datasets/GasStation/data_singleclass.yaml')
# Out:
# Ultralytics YOLOv8.0.58 🚀 Python-3.7.16 torch-1.13.1 CPU
# Model summary (fused): 168 layers, 3006233 parameters, 0 gradients, 8.1 GFLOPs
# val: Scanning /Users/laurabarseghyan/Desktop/CapstoneProject/datasets/GasStation
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        217       1116      0.973      0.931      0.963      0.792
#                    car        217       1116      0.973      0.931      0.963      0.792
# Speed: 1.9ms preprocess, 161.9ms inference, 0.0ms loss, 0.8ms postprocess per image
# Results saved to runs/detect/val7
# ultralytics.yolo.utils.metrics.DetMetrics object with attributes:
#
# ap_class_index: array([0])
# box: ultralytics.yolo.utils.metrics.Metric object
# confusion_matrix: <ultralytics.yolo.utils.metrics.ConfusionMatrix object at 0x7faf67459050>
# fitness: 0.8090239185565821
# keys: ['metrics/precision(B)', 'metrics/recall(B)', 'metrics/mAP50(B)', 'metrics/mAP50-95(B)']
# ...

# %%
YOLO('object_detection/models/detect/multiclass/weights/yolov8_cars.pt').val('/Users/laurabarseghyan/Desktop/CapstoneProject/datasets/GasStation/data.yaml')
# Out:
# Ultralytics YOLOv8.0.58 🚀 Python-3.7.16 torch-1.13.1 CPU
# Model summary (fused): 168 layers, 3006233 parameters, 0 gradients, 8.1 GFLOPs
# val: Scanning /Users/laurabarseghyan/Desktop/CapstoneProject/datasets/GasStation
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        217       1116        0.9      0.586      0.806      0.592
#                    bus        217          4          1          0      0.649       0.49
#                    car        217       1080      0.949      0.916      0.959      0.766
#                  truck        217         32      0.753      0.844      0.809       0.52
# Speed: 1.7ms preprocess, 146.6ms inference, 0.0ms loss, 0.8ms postprocess per image
# Results saved to runs/detect/val9
# ultralytics.yolo.utils.metrics.DetMetrics object with attributes:
#
# ap_class_index: array([0, 1, 2])
# box: ultralytics.yolo.utils.metrics.Metric object
# ...

# %%
model = YOLO('object_detection/models/detect/singleclass/weights/yolov8_cars.pt')
videos = os.listdir('test_videos')

for vid in videos:
    model.predict('test_videos/'+vid, save=True, line_thickness=2)
# Out:
#     WARNING ⚠️ stream/video/webcam/dir predict source will accumulate results in RAM unless `stream=True` is passed,
#     causing potential out-of-memory errors for large sources or long-running streams/videos.
#
#     Usage:
#         results = model(source=..., stream=True)  # generator of Results objects
#         for r in results:
#             boxes = r.boxes  # Boxes object for bbox outputs
#             masks = r.masks  # Masks object for segment masks outputs
#             probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (1/750) /Users/laurabarseghyan/Desktop/Final/test_videos/Video6.mp4: 384x640 7 cars, 169.7ms
# video 1/1 (2/750) /Users/laurabarseghyan/Desktop/Final/test_videos/Video6.mp4: 384x640 7 cars, 156.9ms
# video 1/1 (3/750) /Users/laurabarseghyan/Desktop/Final/test_videos/Video6.mp4: 384x640 7 cars, 161.4ms
# video 1/1 (4/750) /Users/laurabarseghyan/Desktop/Final/test_videos/Video6.mp4: 384x640 7 cars, 172.9ms
# ...

# %%
model = YOLO('yolov8n.pt')

for vid in videos:
    model.predict('test_videos/'+vid, save=True, line_thickness=2, classes=[1,2,3,5,7])
# Out:
#     WARNING ⚠️ stream/video/webcam/dir predict source will accumulate results in RAM unless `stream=True` is passed,
#     causing potential out-of-memory errors for large sources or long-running streams/videos.
#
#     Usage:
#         results = model(source=..., stream=True)  # generator of Results objects
#         for r in results:
#             boxes = r.boxes  # Boxes object for bbox outputs
#             masks = r.masks  # Masks object for segment masks outputs
#             probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (1/750) /Users/laurabarseghyan/Desktop/Final/test_videos/Video6.mp4: 384x640 4 cars, 1 truck, 156.9ms
# video 1/1 (2/750) /Users/laurabarseghyan/Desktop/Final/test_videos/Video6.mp4: 384x640 4 cars, 1 truck, 156.7ms
# video 1/1 (3/750) /Users/laurabarseghyan/Desktop/Final/test_videos/Video6.mp4: 384x640 4 cars, 1 truck, 161.1ms
# ...
