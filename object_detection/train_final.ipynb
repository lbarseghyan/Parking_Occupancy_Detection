# %%
# !pip install ultralytics
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 562.2/562.2 kB 10.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 201.7/201.7 kB 17.0 MB/s eta 0:00:00
# ...

# %%
import os
from ultralytics import YOLO
from google.colab import files, drive

# %%
drive.mount('/content/drive')
# %cd /content/drive/MyDrive/Capstone_shared/
# Out:
# Mounted at /content/drive
# /content/drive/MyDrive/Capstone_shared

# %%
model_trained = YOLO("yolov8n.pt").train(data="/content/drive/MyDrive/Capstone_shared/datasets/GasStation/data_singleclass.yaml", single_cls = True, epochs = 200)
# Out:
# Ultralytics YOLOv8.0.87 🚀 Python-3.9.16 torch-2.0.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
model_trained = YOLO("yolov8n.pt").train(data="/content/drive/MyDrive/Capstone_shared/datasets/GasStation/data_singleclass.yaml", single_cls = True, epochs = 200)
# Out:
# Ultralytics YOLOv8.0.90 🚀 Python-3.10.11 torch-2.0.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...
